# %% [markdown]
# #**Exploração e análise de dados**#
#
# > *Dados:*
#
#
# Os dados abaixo são informaçõe de cliente de um banco, onde as informações contam com as seguintes colunas para melhor entendimento da análise:
#
# * idade = idade do cliente
# * sexo = sexo do cliente (F ou M)
# * dependentes = número de dependentes do cliente
# * escolaridade = nível de escolaridade
# * salario_anual = faixa salarial do cliente
# * tipo_cartao = tipo do cartão do cliente
# * qtd_produtos = quantidadde de produtos compradoss nos ultimos 12 meses
# * interacoes_12m = quantidade de interações/transações feitas nos ultimos 12 meses
# * meses_inativo_12m = quantidade de meses em que o cliente esteve inativo
# * limite_credito = limite de credito do cliente
# * valor_transacoes_12m = valor das transações feitas nos ultimos 12 meses
# * qtd_transacoes_12m = quantidade de transações feitas nos ultimos 12 meses
#
# > Exploração dos dados:
#
# Na primeira etapa da análise e compreender o que nossos dados nós mostram:
#
# **Quantas informação possuimos em nossa base de dados:**
#
# *Query 1:*
# SELECT count(*) FROM credito
#
# > RESPOSTA: 2564 linhas
#
# **Quais são esses dados:**
#
# *Query 2:* SELECT * FROM credito LIMIT 10
#
# ![ebac.png](data:image/png;base64,...)
#
# **Análise de dados**
#
# Uma vez em que buscamos entender mais sobre o nosso banco de dados para saber quais informações temos, podemos análisar para enterder o que está acontecendo em nosso banco de dados.
#
# >Vamos para as pergunstas:
#
# *Em nosso banco de dados quais são os tipos de cartões utilizados pelos clientes?*
#
# *Query 3:* select count(*), tipo_cartao from credito group by tipo_cartao
#
#
# ![imagem_2024-01-03_223101385.png](data:image/png;base64,...)
#
# *Qual a media de limite de Credito para clientes homens e para clientes mulheres?*
#
# *Query 4:*
# SELECT avg(limite_credito) as media_limite, sexo
# from credito
# where sexo != 'na'
# group by sexo, salario_anual
# order by sexo desc
#
# ![imagem_2024-01-03_234613986.png](data:image/png;base64,...)
#
# > Os clientes com menor Faixa salaríal apresentam menor limite de crédito
#
# **Conclusão**
#
# Essa foram algumas das análises obtidas atraves do dataset de crédito.
#
# Alguns inshts interessantes:
#
# * O maior limite de crédito é de um cartão Blue,
# * A faixa salarial impacta diretamente no limite,
# * A maior parte dos clientes são Homens,
# * Grande parte dos clientes possuem rende de até 40k,
# * Salario anual acima de 60k só estão presentes no sexo masculino.
#
# *Uma melhor exploração nos dados pode explicar o porque das mulheres não possuirem salario anual supereior a 60k é possuirem menor limite de crédito.
